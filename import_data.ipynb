# %%
import pandas as pd

# %%
df=pd.read_csv('Learner Data.csv')
df.head(10)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9124\1040659537.py:1: DtypeWarning: Columns (3,4,6,10,15,19,20,26,28,30,31,32,34,35,41,219,220,221,222,223,224,225,226,227,228,229,230,231,232,233,234,235,236,237,238,239,240,241,242,243,244,245,246,247,248,249,250,251,252,253,254,255) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('Learner Data.csv')
#                                              pk  \
# 0                                      Learner#
# 1  Learner#838ff3db-f3de-4ae4-9c06-29632039ad2c
# 2                                      Learner#
# 3  Learner#e84aea65-34d3-440a-bf04-f877d3bc5ce2
# 4  Learner#f9f52ded-a970-4700-830a-c13df19749e6
# 5  Learner#8d4c12bb-211d-459f-8b2d-653095f9b529
# 6  Learner#6f39a383-aa51-4642-8995-61e49649f6d8
# 7  Learner#c577f426-abe7-4f04-a8db-92cff7ca86bd
# 8  Learner#e84aea65-34d3-440a-bf04-f877d3bc5ce2
# 9  Learner#6ca14518-2878-4135-adc1-06e6f0605e0b
#
# ...

# %%
df.shape
# Out:
# (15029, 256)

# %%
df.info
# Out:
# <bound method DataFrame.info of                                                  pk  \
# 0                                          Learner#
# 1      Learner#838ff3db-f3de-4ae4-9c06-29632039ad2c
# 2                                          Learner#
# 3      Learner#e84aea65-34d3-440a-bf04-f877d3bc5ce2
# 4      Learner#f9f52ded-a970-4700-830a-c13df19749e6
# ...                                             ...
# 15024                                      Learner#
# 15025  Learner#fc1ab387-95e3-42fd-9c6e-d519f4df2861
# 15026                                      Learner#
# 15027                                      Learner#
# 15028                                      Learner#
#
#                                        sk assigned_cohort    fee  status  \
# 0      Learner#0000000010Z56C78JF7M6VQXQ2             NaN    0.0     NaN
# 1      Learner#000000000G1RYRMC22H9RYCYSP             NaN    NaN  1010.0
# 2      Learner#0000000010K1EA93ZGXZA0S5NG             NaN   33.0     NaN
# ...

# %%
pip install pandas sqlalchemy psycopg2-binary
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# For Opportunity data

# %%
import pandas as pd
from sqlalchemy import create_engine
from urllib.parse import quote_plus

# -----------------------------
# PostgreSQL Connection Details
# -----------------------------
username = "postgres"
password = quote_plus("Tamanna@196")
host = "localhost"
port = "5432"
database = "Exceleratedb"

# -----------------------------
# CSV Path
# -----------------------------
csv_file = r"D:\Excelerate\Opportunity Data.csv"

# -----------------------------
# Read CSV
# -----------------------------
df = pd.read_csv(csv_file)

print("Dataset Loaded Successfully")
print(df.head())

# -----------------------------
# Create PostgreSQL Engine
# -----------------------------
engine = create_engine(
    f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}"
)

# -----------------------------
# Upload Dataset
# -----------------------------
df.to_sql(
    name="opportunity",
    con=engine,
    if_exists="replace",   # Creates a new table
    index=False
)

print("Table Created Successfully!")
# Out:
# Dataset Loaded Successfully
#              pk                          opportunity_id  \
# 0  Opportunity#  Opportunity#000000000GBD0AX3Z6VYRG7R75
# 1  Opportunity#  Opportunity#000000000GFKZ4N696ZF8V2WM8
# 2  Opportunity#  Opportunity#0000000010ZFE0ZS22FA3Q62R4
# 3  Opportunity#  Opportunity#000000000GG34EPWZAJ6BDPQKP
# 4  Opportunity#  Opportunity#000000000GQHDFWJ9R1HQJ4WTE
#
#                                                Badge  \
# 0  {"sk":"Badge#000000000G87VEXNYKKKTJTKE9","ref_...
# 1  {"sk":"Badge#000000000GAR6YSZ2B71HZJPM3","ref_...
# 2                                                NaN
# 3  {"sk":"Badge#000000000GGQG1DZ2TSSHR55G9","ref_...
# 4                                                NaN
#
#                                          CareerAddOn     category     code  \
# 0                                                NaN  Competition  M636023
# 1  {"sk":"CareerAddOn#000000000G8FT85VQ6BFCT0M0K"...       Career  A463411
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine
from urllib.parse import quote_plus

# -----------------------------
# PostgreSQL Connection Details
# -----------------------------
username = "postgres"
password = quote_plus("Tamanna@196")
host = "localhost"
port = "5432"
database = "Exceleratedb"

# -----------------------------
# CSV Path
# -----------------------------
csv_file = r"D:\Excelerate\Learner Data.csv"

# -----------------------------
# Read CSV
# -----------------------------
df = pd.read_csv(csv_file)

print("Dataset Loaded Successfully")
print(df.head())

# -----------------------------
# Create PostgreSQL Engine
# -----------------------------
engine = create_engine(
    f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}"
)

# -----------------------------
# Upload Dataset
# -----------------------------
df.to_sql(
    name="learner",
    con=engine,
    if_exists="replace",   # Creates a new table
    index=False
)

print("Table Created Successfully!")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9124\2463295298.py:22: DtypeWarning: Columns (3,4,6,10,15,19,20,26,28,30,31,32,34,35,41,219,220,221,222,223,224,225,226,227,228,229,230,231,232,233,234,235,236,237,238,239,240,241,242,243,244,245,246,247,248,249,250,251,252,253,254,255) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# Dataset Loaded Successfully
#                                              pk  \
# 0                                      Learner#
# 1  Learner#838ff3db-f3de-4ae4-9c06-29632039ad2c
# 2                                      Learner#
# 3  Learner#e84aea65-34d3-440a-bf04-f877d3bc5ce2
# 4  Learner#f9f52ded-a970-4700-830a-c13df19749e6
#
#                                    sk assigned_cohort   fee  status  \
# 0  Learner#0000000010Z56C78JF7M6VQXQ2             NaN   0.0     NaN
# 1  Learner#000000000G1RYRMC22H9RYCYSP             NaN   NaN  1010.0
# ...
